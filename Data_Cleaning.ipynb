# %% [markdown]
# <a href="https://colab.research.google.com/github/newbie-sandy/datasci_1_loading/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data cleaning
#
# What's unique about each row?

# %% [markdown]
# Load Packages

# %%
import pandas as pd

# %% [markdown]
# Load data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK2/data/Hospital_Cost_Report_2019.csv')

# %% [markdown]
# #Data interpretation
# What's unique about each row?

# %% [markdown]
# # Inspecting shape

# %%
print('number of rows:', df.shape[0])
print('number of columns:', df.shape[1])
print('data size:', df.size)
print(df.shape)
# Out:
# number of rows: 6118
# number of columns: 126
# data size: 770868

# %% [markdown]
# Why .shape[0]? 猜想是表达1d，二进制里1是0，1是2
# 问题来了，三维数据的shape里第三位是 .shape[10]吗？:

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### 获取数据样本

# %%
df.tail(5)
# Out:
#       rpt_rec_num  Provider CCN                         Hospital Name  \
# 6113       713551         61315                YUMA DISTRICT HOSPITAL
# 6114       707159         30013          YUMA REGIONAL MEDICAL CENTER
# 6115       685609         33034  YUMA REHABILITATION HOSPITAL  AN AFF
# 6116       687770        192041        ZACHARY-AMG SPECIALTY HOSPITAL
# 6117       708981         50228      ZUCKERBERG SAN FRANCISCO GENERAL
#
#                Street Address           City State Code Zip Code  \
# 6113     1000 WEST 8TH AVENUE           YUMA         CO   80759-
# 6114          2400 S AVENUE A           YUMA         AZ    85364
# 6115     901 WEST 24TH STREET           YUMA         AZ    85364
# 6116  4601 MCHUGH RD.  BLDG B        ZACHARY         LA    70791
# 6117      1001 POTRERO AVENUE  SAN FRANCISCO         CA   94110-
#
#                      County  Medicare CBSA Number Rural Versus Urban  ...  \
# 6113                   YUMA               99906.0                  R  ...
# ...

# %%
df.sample(5)
# Out:
#       rpt_rec_num  Provider CCN                       Hospital Name  \
# 3984       700478        114010                  PEACHFORD HOSPITAL
# 3761       689307        351315            OAKES COMMUNITY HOSPITAL
# 482        698560        451320          BAYSIDE COMMUNITY HOSPITAL
# 3903       707919         50204    PALMDALE REGIONAL MEDICAL CENTER
# 3401       711331        261337  MISSOURI BAPTIST HOSPITAL SULLIVAN
#
#                   Street Address      City State Code Zip Code       County  \
# 3984         2151 PEACHFORD ROAD   ATLANTA         GA    30338          NaN
# 3761            314 SOUTH 8TH ST     OAKES         ND    58474       DICKEY
# 482           200 HOSPTIAL DRIVE   ANAHUAC         TX    77514     CHAMBERS
# 3903  38600 MEDICAL CENTER DRIVE  PALMDALE         CA    93551  LOS ANGELES
# 3401  751 SAPPINGTON BRIDGE ROAD  SULLIVAN         MO    63080     CRAWFORD
#
#       Medicare CBSA Number Rural Versus Urban  ...  \
# ...

# %%
one_percent = int(df.shape[0] * .01)
df.sample(one_percent)
# Out:
#       rpt_rec_num  Provider CCN                         Hospital Name  \
# 850        711107        264008        CENTER FOR BEHAVIORAL MEDICINE
# 1308       717790        161327                 DAVIS COUNTY HOSPITAL
# 919        714361        280081                   CHI HEALTH IMMANUEL
# 419        689415         52031           BARLOW RESPIRATORY HOSPITAL
# 625        669547        131301           BOUNDARY COMMUNITY HOSPITAL
# ...           ...           ...                                   ...
# 1471       707757        230230            EDWARD W. SPARROW HOSPITAL
# 3704       705101        140010    NORTHSHORE UNIVERSITY HEALTHSYSTEM
# 6026       710049         50735      WHITTIER HOSPITAL MEDICAL CENTER
# 2825       716461        104018          LIFESTREAM BEHAVIORAL CENTER
# 5417       710165        440120  TENNOVA HEALTHCARE - TURKEY CREEK MC
#
#               Street Address           City State Code    Zip Code  \
# ...

# %% [markdown]
# ### 提取某列数据

# %%
df.columns
# Out:
# Index(['rpt_rec_num', 'Provider CCN', 'Hospital Name', 'Street Address',
#        'City', 'State Code', 'Zip Code', 'County', 'Medicare CBSA Number',
#        'Rural Versus Urban',
#        ...
#        'Net Income from Service to Patients', 'Total Other Income',
#        'Total Income', 'Total Other Expenses', 'Net Income',
#        'Cost To Charge Ratio', 'Net Revenue from Medicaid', 'Medicaid Charges',
#        'Net Revenue from Stand-Alone SCHIP', 'Stand-Alone SCHIP Charges'],
#       dtype='object', length=126)

# %%
list(df)
# Out:
# ['rpt_rec_num',
#  'Provider CCN',
#  'Hospital Name',
#  'Street Address',
#  'City',
#  'State Code',
#  'Zip Code',
#  'County',
#  'Medicare CBSA Number',
#  'Rural Versus Urban',
#  'CCN Facility Type',
#  'Provider Type',
#  'Type of Control',
#  'Fiscal Year Begin Date',
#  'Fiscal Year End Date',
#  'FTE - Employees on Payroll',
#  'Number of Interns and Residents (FTE)',
#  'Total Days Title V',
#  'Total Days Title XVIII',
#  'Total Days Title XIX',
#  'Total Days (V + XVIII + XIX + Unknown)',
#  'Number of Beds',
#  'Total Bed Days Available',
#  'Total Discharges Title V',
#  'Total Discharges Title XVIII',
#  'Total Discharges Title XIX',
#  'Total Discharges (V + XVIII + XIX + Unknown)',
#  'Total Days Title V + Total for all Subproviders',
#  'Total Days Title XVIII + Total for all Subproviders',
#  'Total Days Title XIX + Total for all Subproviders',
#  'Total Days (V + XVIII + XIX + Unknown) + Total for all Subproviders',
# ...

# %%
net_income = df[['Hospital Name','Net Income', 'Cost To Charge Ratio']]
net_income.head(5)
# Out:
#                          Hospital Name  Net Income  Cost To Charge Ratio
# 0  1125 SIR FRANCIS DRAKE OPERATING CO   4167716.0                   NaN
# 1        ABBEVILLE AREA MEDICAL CENTER   -797432.0              0.525693
# 2           ABBEVILLE GENERAL HOSPITAL   1796757.0              0.308672
# 3         ABBOTT NORTHWESTERN HOSPITAL  50563800.0              0.268633
# 4                  ABILENE REG MED CTR   3386811.0              0.100260

# %%
net_income.describe()
# Out:
#          Net Income  Cost To Charge Ratio
# count  6.013000e+03           4691.000000
# mean   1.026506e+07              1.031930
# std    7.186361e+07             33.677305
# min   -9.800109e+08              0.055417
# 25%   -9.019650e+05              0.199217
# 50%    1.577785e+06              0.290734
# 75%    1.035629e+07              0.473881
# max    2.209102e+09           2280.353040

# %% [markdown]
# ### 透视表，pivot table

# %%
df.groupby('Net Income').sum()

#以某列为首列，.sum这里使用不了？summary可能是说summary
# Out:
# <ipython-input-26-b7763368610f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Net Income').sum()
#                rpt_rec_num  Provider CCN  Medicare CBSA Number  Provider Type  \
# Net Income
# -9.800109e+08       708734         50138               31084.0              1
# -9.369297e+08       705592        220071               14454.0              5
# -8.120480e+08       716033        100038               22744.0              5
# -7.346014e+08       700333         50076               41884.0              1
# -7.092566e+08       710762         50072               36084.0              1
# ...                    ...           ...                   ...            ...
#  9.490729e+08       705112        240010               40340.0              1
# ...

# %% [markdown]
# ### 创造去掉空格和特殊符号功能，并应用于所有列
# import re
# def clean_value(value):
#     cleaned_value =
#
# for column in df.columns:

# %% [markdown]
# ## 查询数据格式与修改格式

# %%
df.dtypes
# Out:
# rpt_rec_num                             int64
# Provider CCN                            int64
# Hospital Name                          object
# Street Address                         object
# City                                   object
#                                        ...
# Cost To Charge Ratio                  float64
# Net Revenue from Medicaid             float64
# Medicaid Charges                      float64
# Net Revenue from Stand-Alone SCHIP    float64
# Stand-Alone SCHIP Charges             float64
# Length: 126, dtype: object
